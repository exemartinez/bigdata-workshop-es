# %% [markdown]
# # Load up the dataset

# %%
import pandas as pd

df_pickle = '/dataset/gw_gravity_spy_dataframe.pickle'
df = pd.read_pickle(df_pickle)

# %%
#filter the training set
train_set= df.where(df['sample_type']=='train')

# %%
train_set.head()
# Out:
#      event_time  ifo     peak_time  peak_time_ns    start_time  start_time_ns  \
# 0  1.134216e+09   L1  1.134216e+09   931639909.0  1.134216e+09    832031011.0
# 1           NaN  NaN           NaN           NaN           NaN            NaN
# 2  1.127425e+09   L1  1.127425e+09   976317882.0  1.127425e+09    960937023.0
# 3           NaN  NaN           NaN           NaN           NaN            NaN
# 4           NaN  NaN           NaN           NaN           NaN            NaN
#
#    duration   search  process_id  event_id  ...  param_one_name  \
# 0   0.18750  Omicron         0.0      21.0  ...           phase
# 1       NaN      NaN         NaN       NaN  ...             NaN
# 2   0.04688  Omicron         0.0     218.0  ...           phase
# 3       NaN      NaN         NaN       NaN  ...             NaN
# 4       NaN      NaN         NaN       NaN  ...             NaN
#
#    param_one_value  gravityspy_id    label  sample_type  \
# ...

# %%
train_set.shape
# Out:
# (7966, 29)

# %%
array = train_set.values
array[1,:]
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan], dtype=object)

# %%
from sklearn.neural_network import MLPClassifier
